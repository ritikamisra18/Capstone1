# %% [markdown]
# **Working With numpy Matrics(Multidemsional Data)**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew, kurtosis
from scipy.stats import pearsonr, spearmanr
from scipy.stats import zscore

# %%
male_df=pd.read_csv('nhanes adult male bmx2020 (1).csv')
male_df.head(8)
# Out:
#    BMXWT  BMXHT  BMXARML  BMXLEG  BMXARMC  BMXHIP  BMXWAIST
# 0   98.8  182.3     42.0    40.1     38.2   108.2     120.4
# 1   74.3  184.2     41.1    41.0     30.2    94.5      86.8
# 2  103.7  185.3     47.0    44.0     32.0   107.8     109.6
# 3   86.0  167.8     39.5    38.4     29.0   106.4     108.3
# 4   99.4  181.6     40.4    39.9     36.0   120.2     107.0
# 5   90.2  162.5     38.7    38.0     37.3   110.2     116.2
# 6   45.5  159.3     36.2    38.0     24.4    82.0      67.2
# 7   64.0  174.9     37.0    45.0     29.2    88.9      82.5

# %% [markdown]
# Read Data Female BMI

# %%
female_df=pd.read_csv('nhanes adultfemalebmx 2020 checkpoint.csv')
female_df.head(8)
# Out:
#    BMXWT  BMXHT  BMXARML  BMXLEG  BMXARMC  BMXHIP  BMXWAIST
# 0   97.1  160.2     34.7    40.8     35.8   126.1     117.9
# 1   91.1  152.7     33.5    33.0     38.5   125.5     103.1
# 2   73.0  161.2     37.4    38.0     31.8   106.2      92.0
# 3   61.7  157.4     38.0    34.7     29.0   101.0      90.5
# 4   55.4  154.6     34.6    34.0     28.3    92.5      73.2
# 5   62.0  144.7     32.5    34.2     29.8   106.7      84.8
# 6   66.2  166.5     37.5    37.6     32.0    96.3      95.7
# 7   75.9  154.5     35.4    37.6     32.7   107.7      98.7

# %% [markdown]
# **Read the two files as numpy matrices named male and female. Each matrix consists
# of seven**

# %%
male_df = pd.read_csv('nhanes adult male bmx2020 (1).csv')
female_df = pd.read_csv('nhanes adultfemalebmx 2020 checkpoint.csv')
male = male_df.values 
female = female_df.values
print('Male matrix shape:', male.shape)
print('Female matrix shape:', female.shape)
# Out:
# Male matrix shape: (4081, 7)
# Female matrix shape: (4221, 7)

# %% [markdown]
# ***On a single plot (use matplotlib.pytplot.subplot), draw two histograms: for female
# weights (top subfigure). and for male weights (bottom subfigure) Call
# matplotlib.pyplot.xlim to make the xaxis limits identical for both subfigures (work out the
# appropriate limits yourself)**

# %%
male_df = pd.read_csv('nhanes adult male bmx2020 (1).csv')
female_df = pd.read_csv('nhanes adultfemalebmx 2020 checkpoint.csv')

male_weights = male_df['BMXWT'].values #male weight
female_weights = female_df['BMXWT'].values #female weight

# Create a figure and two subplots
fig, (ax1, ay2) = plt.subplots(2, 1, figsize=(10, 10), sharex=True)

# Plot histogram for female weights
ax1.hist(female_weights, bins=15, color='pink', edgecolor='black')
ax1.set_title('Histogram of Female Weights')
ax1.set_ylabel('Frequency')
ax1.grid(axis='y')

# Plot histogram for male weights
ay2.hist(male_weights, bins=15, color='green', edgecolor='black')
ay2.set_title('Histogram of Male Weights')
ay2.set_ylabel('Frequency')
ay2.grid(axis='y')

# Set identical x-axis limits
plt.xlim(40, 150)  # Adjust limits based on expected weight range for both genders

# Set common x-label for both subplots
ay2.set_xlabel('Weight (kg)')
ax1.set_xlabel('Weight (kg)')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# **Call matplotlib.pyplot.boxplot to draw a box-and-whisker plot, with two boxes side by
# side, giving the male and female weights so that they can be compared to each other.
# Note that the boxplot function can be fed with a list of two vectors like [female_weights,
# male_weights]. In your own words, discuss the results.**

# %%
#create the box-and-whisker plot
male_df = pd.read_csv('nhanes adult male bmx2020 (1).csv')
female_df = pd.read_csv('nhanes adultfemalebmx 2020 checkpoint.csv')

male_weights = male_df['BMXWT'].values  # Male weights
female_weights = female_df['BMXWT'].values  # Female weights

plt.figure(figsize=(10, 6))
plt.boxplot([female_weights, male_weights], labels=['Female', 'Male'])

plt.title('Box-and-Whisker Plot of Weights for Males and Females')
plt.ylabel('Weight (kg)')
plt.grid(axis='y')
plt.show()
# Out:
# C:\Users\Ritika Mishra\AppData\Local\Temp\ipykernel_12112\3950687339.py:11: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([female_weights, male_weights], labels=['Female', 'Male'])

# %% [markdown]
# **Compute the basic numerical aggregates of the male and female weights (measures
# of location, dispersion, and shape). In your own words, describe and compare the two
# distributions (e.g., are they left skewed, which one has more dispersion, and so forth).**

# %%
# Extract the weight columns for male and female
male_weights = dataframe['BMXWT']
female_weights = df['BMXWT']

# Basic aggregates for males
male_mean = np.mean(male_weights)
male_median = np.median(male_weights)
male_std = np.std(male_weights)
male_iqr = np.percentile(male_weights, 75) - np.percentile(male_weights, 25)
male_skewness = skew(male_weights)
male_kurtosis = kurtosis(male_weights)

# Basic aggregates for females
female_mean = np.mean(female_weights)
female_median = np.median(female_weights)
female_std = np.std(female_weights)
female_iqr = np.percentile(female_weights, 75) - np.percentile(female_weights, 25)
female_skewness = skew(female_weights)
female_kurtosis = kurtosis(female_weights)

# Display results
male_aggregates = {
    'Mean': male_mean,
    'Median': male_median,
    'Standard Deviation': male_std,
    'Interquartile Range (IQR)': male_iqr,
    'Skewness': male_skewness,
    'Kurtosis': male_kurtosis
}

female_aggregates = {
    'Mean': female_mean,
    'Median': female_median,
    'Standard Deviation': female_std,
    'Interquartile Range (IQR)': female_iqr,
    'Skewness': female_skewness,
    'Kurtosis': female_kurtosis
}

# Print aggregates
print("Male Weight Aggregates:")
print(pd.Series(male_aggregates))
print("\nFemale Weight Aggregates:")
print(pd.Series(female_aggregates))
# Out:
# Male Weight Aggregates:
# Mean                         88.364543
# Median                       85.000000
# Standard Deviation           21.418937
# Interquartile Range (IQR)    26.500000
# Skewness                      0.984281
# Kurtosis                      1.474288
# dtype: float64
#
# Female Weight Aggregates:
# Mean                         77.403791
# Median                       73.600000
# Standard Deviation           21.542508
# Interquartile Range (IQR)    27.100000
# Skewness                      1.033361
# Kurtosis                      1.400968
# dtype: float64

# %% [markdown]
# **Conclusion: The Male aggregate high than the female

# %% [markdown]
# **To the female matrix, add the eight column which gives the body mass indices of all
# the female participants.**

# %%
# Calculate BMI for female participants
df['BMI'] = df['BMXWT'] / (df['BMXHT'] / 100) ** 2
print(df.head(8))
# Out:
#    BMXWT  BMXHT  BMXARML  BMXLEG  BMXARMC  BMXHIP  BMXWAIST        BMI
# 0   97.1  160.2     34.7    40.8     35.8   126.1     117.9  37.835041
# 1   91.1  152.7     33.5    33.0     38.5   125.5     103.1  39.069720
# 2   73.0  161.2     37.4    38.0     31.8   106.2      92.0  28.092655
# 3   61.7  157.4     38.0    34.7     29.0   101.0      90.5  24.904378
# 4   55.4  154.6     34.6    34.0     28.3    92.5      73.2  23.178791
# 5   62.0  144.7     32.5    34.2     29.8   106.7      84.8  29.611106
# 6   66.2  166.5     37.5    37.6     32.0    96.3      95.7  23.879736
# 7   75.9  154.5     35.4    37.6     32.7   107.7      98.7  31.796902

# %%
dataframe['BMI'] = dataframe['BMXWT'] / (dataframe['BMXHT'] / 100) ** 2
print(dataframe.head(8))
# Out:
#    BMXWT  BMXHT  BMXARML  BMXLEG  BMXARMC  BMXHIP  BMXWAIST        BMI
# 0   98.8  182.3     42.0    40.1     38.2   108.2     120.4  29.729226
# 1   74.3  184.2     41.1    41.0     30.2    94.5      86.8  21.898258
# 2  103.7  185.3     47.0    44.0     32.0   107.8     109.6  30.201459
# 3   86.0  167.8     39.5    38.4     29.0   106.4     108.3  30.543200
# 4   99.4  181.6     40.4    39.9     36.0   120.2     107.0  30.140795
# 5   90.2  162.5     38.7    38.0     37.3   110.2     116.2  34.158580
# 6   45.5  159.3     36.2    38.0     24.4    82.0      67.2  17.929982
# 7   64.0  174.9     37.0    45.0     29.2    88.9      82.5  20.921863

# %% [markdown]
# **. Create a new matrix zfemale being a version of the female dataset with all its columns
# standardised (by computing the z-scores of each column).**

# %%
# Read the CSV files
male_df = pd.read_csv('nhanes adult male bmx2020 (1).csv')
female_df = pd.read_csv('nhanes adultfemalebmx 2020 checkpoint.csv')

# Convert DataFrames to NumPy matrices
male = male_df.values
female = female_df.values

# Calculate BMI for females
weights = female[:, 0]  # Weight in kg
heights = female[:, 1]  # Height in cm
heights_m = heights / 100  # Convert height to meters

bmi = weights / (heights_m ** 2)

female_with_bmi = np.column_stack((female, bmi))

print('Female matrix shape with BMI:', female_with_bmi.shape)
# Out:
# Female matrix shape with BMI: (4221, 8)

# %% [markdown]
# **8. Draw a scatterplot matrix (pairplot) for the standardised versions of height, weight,
# waist circumference, hip circumference, and BMI of the females (based on zfemale).
# Compute Pearson’s and Spearman’s correlation coefficients for all pairs of variables.
# Interpret the obtained results.**

# %%
# Read the CSV files
male_df = pd.read_csv('nhanes adult male bmx2020 (1).csv')
female_df = pd.read_csv('nhanes adultfemalebmx 2020 checkpoint.csv')

male = male_df.values
female = female_df.values

weights = female[:, 0]  # Weight in kg
heights = female[:, 1]  # Height in cm
heights_m = heights / 100  # Convert height to meters
bmi = weights / (heights_m ** 2)

female_with_bmi = np.column_stack((female, bmi))

mean = np.mean(female_with_bmi, axis=0)  # Mean of each column
std_dev = np.std(female_with_bmi, axis=0)  # Standard deviation of each column

# Calculate z-scores
zfemale = (female_with_bmi - mean) / std_dev

print('Standardized female matrix shape:', zfemale.shape)
print(zfemale[:5])
# Out:
# Standardized female matrix shape: (4221, 8)
# [[ 0.91429508  0.00895038 -0.56739463  1.13298804  0.55084546  1.08316157
#    1.11578462  0.9969677 ]
#  [ 0.63577599 -1.05306843 -1.07893145 -1.29349161  1.03221804  1.04475528
#    0.265089    1.15617483]
#  [-0.2044233   0.15055289  0.5835632   0.26194406 -0.1622991  -0.19064688
#   -0.37293272 -0.25927501]
#  [-0.7289676  -0.38753664  0.83933161 -0.76464348 -0.66150029 -0.52350135
#   -0.45915188 -0.67039085]
#  [-1.02141265 -0.78402366 -0.6100227  -0.98240447 -0.78630059 -1.06759039
#   -1.45354609 -0.89289859]]

# %%
male_df = pd.read_csv('nhanes adult male bmx2020 (1).csv')
female_df = pd.read_csv('nhanes adultfemalebmx 2020 checkpoint.csv')
male = male_df.values
female = female_df.values
weights = female[:, 0]  # Weight in kg
heights = female[:, 1]  # Height in cm
heights_m = heights / 100  # Convert height to meters
bmi = weights / (heights_m ** 2)

# Add the BMI as the eighth column to the female matrix
female_with_bmi = np.column_stack((female, bmi))

# Standardizing the female dataset (zfemale)
mean = np.mean(female_with_bmi, axis=0)  # Mean of each column
std_dev = np.std(female_with_bmi, axis=0)  # Standard deviation of each column
zfemale = (female_with_bmi - mean) / std_dev

# Create a DataFrame for visualization
variables_of_interest = zfemale[:, [1, 0, 6, 5, 7]]  # Height, Weight, Waist, Hip, BMI
columns = ['Height (z)', 'Weight (z)', 'Waist (z)', 'Hip (z)', 'BMI (z)']
zfemale_df = pd.DataFrame(variables_of_interest, columns=columns)

# Step 3: Draw the scatterplot matrix
sns.pairplot(zfemale_df)
plt.suptitle('Scatterplot Matrix of Standardized Female Variables', y=1.02)
plt.show()

# Step 4: Compute Pearson’s and Spearman’s correlation coefficients
correlation_matrix_pearson = zfemale_df.corr(method='pearson')
correlation_matrix_spearman = zfemale_df.corr(method='spearman')

print("Pearson Correlation Coefficients:\n", correlation_matrix_pearson)
print("\nSpearman Correlation Coefficients:\n", correlation_matrix_spearman)
# Out:
# Pearson Correlation Coefficients:
#              Height (z)  Weight (z)  Waist (z)   Hip (z)   BMI (z)
# Height (z)    1.000000    0.345496   0.126547  0.202895  0.033077
# Weight (z)    0.345496    1.000000   0.904550  0.946553  0.945900
# Waist (z)     0.126547    0.904550   1.000000  0.897407  0.921198
# Hip (z)       0.202895    0.946553   0.897407  1.000000  0.944199
# BMI (z)       0.033077    0.945900   0.921198  0.944199  1.000000
#
# Spearman Correlation Coefficients:
#              Height (z)  Weight (z)  Waist (z)   Hip (z)   BMI (z)
# Height (z)    1.000000    0.338860   0.108587  0.205405  0.019897
# Weight (z)    0.338860    1.000000   0.900169  0.946634  0.937999
# Waist (z)     0.108587    0.900169   1.000000  0.888037  0.923114
# Hip (z)       0.205405    0.946634   0.888037  1.000000  0.934196
# BMI (z)       0.019897    0.937999   0.923114  0.934196  1.000000

# %%
# Read the CSV files
male_df = pd.read_csv('nhanes adult male bmx2020 (1).csv')
female_df = pd.read_csv('nhanes adultfemalebmx 2020 checkpoint.csv')

# Convert DataFrames to NumPy matrices
male = male_df.values
female = female_df.values

# Calculate BMI for females (if not already done)
weights_female = female[:, 0]  # Weight in kg
heights_female = female[:, 1]  # Height in cm
heights_female_m = heights_female / 100  # Convert height to meters
bmi_female = weights_female / (heights_female_m ** 2)

# Add BMI to the female matrix
female_with_bmi = np.column_stack((female, bmi_female))

# Calculate waist circumference to height ratio and waist to hip ratio for females
waist_circumference_female = female_with_bmi[:, 6]  # Waist circumference (BMXWAIST)
height_female = female_with_bmi[:, 1]  # Height (BMXHT)
hip_circumference_female = female_with_bmi[:, 5]  # Hip circumference (BMXHIP)

# Calculate ratios
waist_to_height_ratio_female = waist_circumference_female / height_female
waist_to_hip_ratio_female = waist_circumference_female / hip_circumference_female

# Add new columns to the female matrix
female_with_bmi = np.column_stack((female_with_bmi, waist_to_height_ratio_female, waist_to_hip_ratio_female))

# For males, similar calculations
weights_male = male[:, 0]  # Weight in kg
heights_male = male[:, 1]  # Height in cm
heights_male_m = heights_male / 100  # Convert height to meters
bmi_male = weights_male / (heights_male_m ** 2)

# Add BMI to the male matrix
male_with_bmi = np.column_stack((male, bmi_male))

# Calculate waist circumference to height ratio and waist to hip ratio for males
waist_circumference_male = male_with_bmi[:, 6]  # Waist circumference (BMXWAIST)
height_male = male_with_bmi[:, 1]  # Height (BMXHT)
hip_circumference_male = male_with_bmi[:, 5]  # Hip circumference (BMXHIP)

# Calculate ratios
waist_to_height_ratio_male = waist_circumference_male / height_male
waist_to_hip_ratio_male = waist_circumference_male / hip_circumference_male

# Add new columns to the male matrix
male_with_bmi = np.column_stack((male_with_bmi, waist_to_height_ratio_male, waist_to_hip_ratio_male))

# Display the shapes of the updated matrices
print('Updated Female matrix shape:', female_with_bmi.shape)
print('Updated Male matrix shape:', male_with_bmi.shape)

# Optional: Display the first few rows of the updated matrices
print("\nFirst few rows of the updated Female matrix:\n", female_with_bmi[:5])
print("\nFirst few rows of the updated Male matrix:\n", male_with_bmi[:5])
# Out:
# Updated Female matrix shape: (4221, 10)
# Updated Male matrix shape: (4081, 10)
#
# First few rows of the updated Female matrix:
#  [[ 97.1        160.2         34.7         40.8         35.8
#   126.1        117.9         37.83504078   0.73595506   0.93497224]
#  [ 91.1        152.7         33.5         33.          38.5
#   125.5        103.1         39.06972037   0.67518009   0.82151394]
#  [ 73.         161.2         37.4         38.          31.8
#   106.2         92.          28.09265496   0.5707196    0.86629002]
#  [ 61.7        157.4         38.          34.7         29.
#   101.          90.5         24.90437849   0.57496823   0.8960396 ]
#  [ 55.4        154.6         34.6         34.          28.3
#    92.5         73.2         23.17879132   0.47347995   0.79135135]]
#
# First few rows of the updated Male matrix:
#  [[ 98.8        182.3         42.          40.1         38.2
#   108.2        120.4         29.72922633   0.66044981   1.11275416]
# ...

# %%
male_df = pd.read_csv('nhanes adult male bmx2020 (1).csv')
female_df = pd.read_csv('nhanes adultfemalebmx 2020 checkpoint.csv')

# Convert DataFrames to NumPy matrices
male = male_df.values
female = female_df.values

# Calculate BMI and add to the matrices
weights_male = male[:, 0]  # Weight in kg
heights_male = male[:, 1]  # Height in cm
bmi_male = weights_male / ((heights_male / 100) ** 2)
male_with_bmi = np.column_stack((male, bmi_male))

weights_female = female[:, 0]  # Weight in kg
heights_female = female[:, 1]  # Height in cm
bmi_female = weights_female / ((heights_female / 100) ** 2)
female_with_bmi = np.column_stack((female, bmi_female))

# Calculate waist circumference to height ratio and waist to hip ratio for females
waist_circumference_female = female_with_bmi[:, 6]  # Waist circumference
height_female = female_with_bmi[:, 1]  # Height
hip_circumference_female = female_with_bmi[:, 5]  # Hip circumference

waist_to_height_ratio_female = waist_circumference_female / height_female
waist_to_hip_ratio_female = waist_circumference_female / hip_circumference_female

# Calculate waist circumference to height ratio and waist to hip ratio for males
waist_circumference_male = male_with_bmi[:, 6]  # Waist circumference
height_male = male_with_bmi[:, 1]  # Height
hip_circumference_male = male_with_bmi[:, 5]  # Hip circumference

waist_to_height_ratio_male = waist_circumference_male / height_male
waist_to_hip_ratio_male = waist_circumference_male / hip_circumference_male

# Prepare the data for plotting
data = {
    'Waist-to-Height Ratio': np.concatenate((waist_to_height_ratio_female, waist_to_height_ratio_male)),
    'Waist-to-Hip Ratio': np.concatenate((waist_to_hip_ratio_female, waist_to_hip_ratio_male)),
    'Gender': ['Female'] * len(waist_to_height_ratio_female) + ['Male'] * len(waist_to_height_ratio_male)
}

# Create a DataFrame for seaborn
df_ratios = pd.DataFrame(data)

# Draw the box-and-whisker plot
plt.figure(figsize=(12, 6))
sns.boxplot(x='Gender', y='Waist-to-Height Ratio', data=df_ratios, palette='Set2', width=0.4, fliersize=5, notch=True, boxprops=dict(alpha=0.5))
sns.boxplot(x='Gender', y='Waist-to-Hip Ratio', data=df_ratios, palette='Set2', width=0.4, fliersize=5, notch=True, boxprops=dict(alpha=0.5))

plt.title('Box-and-Whisker Plot of Waist-to-Height and Waist-to-Hip Ratios by Gender')
plt.xlabel('Gender')
plt.ylabel('Ratios')
plt.xticks([0, 1], ['Female', 'Male'])
plt.legend(['Waist-to-Height Ratio', 'Waist-to-Hip Ratio'], loc='upper right')
plt.grid(True)
plt.show()
# Out:
# C:\Users\Ritika Mishra\AppData\Local\Temp\ipykernel_12112\1822505694.py:53: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Gender', y='Waist-to-Height Ratio', data=df_ratios, palette='Set2', width=0.4, fliersize=5, notch=True, boxprops=dict(alpha=0.5))
# C:\Users\Ritika Mishra\AppData\Local\Temp\ipykernel_12112\1822505694.py:54: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Gender', y='Waist-to-Hip Ratio', data=df_ratios, palette='Set2', width=0.4, fliersize=5, notch=True, boxprops=dict(alpha=0.5))

# %%
# Read the female CSV file
female_df = pd.read_csv('nhanes adultfemalebmx 2020 checkpoint.csv')

# Convert DataFrame to NumPy matrix
female = female_df.values

# Calculate BMI
weights_female = female[:, 0]  # Weight in kg
heights_female = female[:, 1]  # Height in cm
heights_female_m = heights_female / 100  # Convert height to meters
bmi_female = weights_female / (heights_female_m ** 2)

# Standardize the measurements (excluding BMI for standardization)
zfemale = np.column_stack((female, bmi_female))
zfemale[:, :-1] = zscore(zfemale[:, :-1], axis=0)  # Standardizing all columns except BMI

# Get BMI values
bmi_values = zfemale[:, -1]  # Last column is BMI

# Find indices of the lowest and highest BMI values
lowest_bmi_indices = np.argsort(bmi_values)[:5]  # 5 lowest BMI
highest_bmi_indices = np.argsort(bmi_values)[-5:]  # 5 highest BMI

# Combine the indices for easy access
selected_indices = np.concatenate((lowest_bmi_indices, highest_bmi_indices))

# Print standardized measurements for selected individuals
print("Standardized Body Measurements for Lowest and Highest BMI Participants:")
print(zfemale[selected_indices, :])  # Print the selected rows
# Out:
# Standardized Body Measurements for Lowest and Highest BMI Participants:
# [[-2.07978523e+00 -1.22299143e+00 -1.54784020e+00 -1.16905675e+00
#   -2.19476110e+00 -2.04054960e+00 -1.94212128e+00  1.42034005e+01]
#  [-1.88017988e+00 -1.89293131e-01 -1.71835247e+00  3.86378917e-01
#   -2.44436170e+00 -1.85491922e+00 -2.05708015e+00  1.46327304e+01]
#  [-1.53667299e+00  1.80730222e+00  6.26191272e-01  5.73031197e-01
#   -2.26607556e+00 -1.67568990e+00 -1.70645560e+00  1.48188240e+01]
#  [-1.84304400e+00 -2.60094385e-01 -2.26370089e-01  5.10813770e-01
#   -2.30173278e+00 -2.25178417e+00 -1.85590213e+00  1.50445610e+01]
#  [-1.61094475e+00  8.86885924e-01 -9.84858847e-02  4.79705057e-01
#   -2.21258971e+00 -1.82931504e+00 -1.71220354e+00  1.54213087e+01]
#  [ 4.24724030e+00  2.92155393e-01  1.86240524e+00 -9.82404472e-01
#    2.36936410e+00  4.10445598e+00  3.81731803e+00  6.41989537e+01]
#  [ 4.45612963e+00  5.04559154e-01  1.69189297e+00 -1.13794804e+00
# ...

# %% [markdown]
# **PROJECT FINISHED**
